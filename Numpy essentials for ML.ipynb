# %% [markdown]
# 1️⃣ Array Creation (Foundation for ML)
#
# These are used to create feature matrices, labels, weights, etc.

# %% [markdown]
# np.array()
# np.zeros()
# np.ones()
# np.empty()
# np.full()
# np.arange()
# np.linspace()
# np.eye()
# np.identity()
# np.random.rand()
# np.random.randn()
# np.random.randint()
# np.random.uniform()
# np.random.normal()

# %% [markdown]
# Use cases:
#
# Initialize weights and bias
#
# Create synthetic datasets
#
# Identity matrices in linear algebra
#
# 2️⃣ Array Properties (Understand Your Data)

# %% [markdown]
# arr.shape, arr.ndim, arr.size, arr.dtype, arr.T

# %% [markdown]
# Why important:
#
# Ensure matrix compatibility
#
# Debug shape mismatches
#
# Transpose feature matrices
#
# 3️⃣ Reshaping & Indexing (Core ML Skill)

# %% [markdown]
# arr.reshape(), arr.flatten(), arr.ravel(), arr.squeeze(), arr.expand_dims(). np.newaxis

# %% [markdown]
# ##### Indexing & slicing:

# %% [markdown]
# arr[i], arr[:, j], arr[mask], arr[start:end]

# %% [markdown]
# Used heavily in:
#
# Feature selection
#
# Batch processing
#
# Data preprocessing
#
# 4️⃣ Mathematical Operations (ML Math Engine)
#
# Element-wise operations:

# %% [markdown]
# np.add(), np.subtract(), np.multiply(), np.divide(), np.power(), np.sqrt(), np.exp(), np.log(), np.abs()

# %% [markdown]
# Examples:
#
# Sigmoid → np.exp
#
# Loss functions → np.log, np.square
#
# 5️⃣ Aggregation & Statistics (Loss & Metrics)

# %% [markdown]
# np.sum(), np.mean(), np.std(), np.var(), np.min(), np.max(), np.argmax(), np.argmin(), np.percentile()

# %% [markdown]
# Used in:
#
# MSE, MAE
#
# Accuracy calculation
#
# Finding predicted class
#
# 6️⃣ Linear Algebra (Heart of ML)

# %% [markdown]
# np.dot(), np.matmul(), np.linalg.inv(), np.linalg.pinv(), np.linalg.det(), np.linalg.eig(), np.linalg.svd(), np.linalg.norm()

# %% [markdown]
# Where used:
#
# Linear regression
#
# Logistic regression
#
# PCA
#
# Gradient descent updates
#
# 8️⃣ Logical Operations & Masking

# %% [markdown]
# np.where(), np.any(), np.all(), np.logical_and(), np.logical_or(), np.logical_not()

# %% [markdown]
# Used for:
#
# Thresholding predictions
#
# Filtering data
#
# Decision boundaries
#
# 9️⃣ Random Utilities (Reproducibility)

# %% [markdown]
# np.random.seed(), np.random.shuffle(), np.random.permutation(), np.random.choice()

# %% [markdown]
# Important for:
#
# Train-test split
#
# Cross-validation
#
# Stochastic gradient descent
#
# 🔟 Sorting & Searching

# %% [markdown]
# np.sort(), np.argsort(), np.searchsorted()

# %% [markdown]
# Used in:
#
# KNN distance sorting
#
# Ranking predictions
#
# Percentile calculations
#
# 1️⃣1️⃣ Stacking & Splitting Arrays

# %% [markdown]
# np.vstack(), np.hstack(), np.column_stack(), np.concatenate(), np.split(), np.array_split()

# %% [markdown]
# Used for:
#
# Combining features
#
# Mini-batch creation
#
# Dataset restructuring
#
# 1️⃣2️⃣ NaN & Missing Value Handling

# %% [markdown]
# np.isnan(), np.isfinite(), np.nanmean(), np.nanstd(), np.nan_to_num()

# %% [markdown]
# Critical for:
#
# Real-world datasets
#
# Cleaning data before training
#
# 1️⃣3️⃣ Comparison Operations

# %% [markdown]
# np.equal(), np.not_equal(), np.greater(), np.less(), np.clip()

# %% [markdown]
# Used in:
#
# Classification thresholds
#
# Gradient clipping
#
# Evaluation metrics
#
# 1️⃣4️⃣ Performance & Vectorization

# %% [markdown]
# np.vectorize(), np.apply_along_axis()

# %% [markdown]
# Helps:
#
# Replace slow Python loops
#
# Write clean ML code
#
# 1️⃣5️⃣ Useful ML-Specific Patterns
#
# One-Hot Encoding

# %% [markdown]
# np.eye(num_classes)[labels]
#
# Accuracy
#
# np.mean(y_pred == y_true)

# %% [markdown]
# 1️⃣6️⃣ Debugging & Safety Tools

# %% [markdown]
# np.set_printoptions(), np.errstate(), np.clip()
