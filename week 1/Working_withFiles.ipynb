# %% [markdown]
# ### 1.1 Writing to a file (create / overwrite)

# %%
with open("data.txt","w") as f:
    f.write("Machine Learning\n")
    f.write("Data Science\n")

# %% [markdown]
# ### Practice.
# #### Create a file notes.txt
# ####  Write 3 lines about Python, ML, AI

# %% [markdown]
# ### 1.2 Reading an entire file

# %%
with open("data.txt","r") as f:
    content = f.read()
print(content)
# Out:
# Machine Learning
# Data Science

# %% [markdown]
# ### Practice
# #### Read notes.txt and print it

# %% [markdown]
# ### 1.3 Reading line by line

# %%
with open('data.txt','r') as f:
    count = 0 
    for line in f:
        count+=1
        print(line.strip())
# This is memory-efficient and used for large datasets.
count
# Out:
# Machine Learning
# Data Science
# 2

# %% [markdown]
# ### 1.4 Appending to a file

# %%
with open('data.txt','a') as f:
    f.write("Deep Learning \n")
    f.write("Date = 14.11.2025\n")

# %%
with open('data.txt','r') as f:
    content = f.read()
print(content)
# Out:
# Machine Learning
# Data Science
# Deep Learning
# Deep Learning
# Date = 14.11.2025

# %% [markdown]
# ### 2.1 Reading file into a list of lines

# %%
with open('data.txt','r') as f:
    lines = f.readlines()
lines
# Out:
# ['Machine Learning\n',
#  'Data Science\n',
#  'Deep Learning \n',
#  'Deep Learning \n',
#  'Date = 14.11.2025\n']

# %% [markdown]
# #### Practice: Remove newline characters from all lines

# %% [markdown]
# ### 2.2 Handling file not found

# %%
try:
    with open("missing.txt","r") as f:
        print(f.read())
except FileNotFoundError:
    print("File Not Found ")
# Out:
# File Not Found

# %% [markdown]
# #### Practice: Add error handling for permission errors

# %% [markdown]
# ### 2.3 Writing processed data to another file

# %%
with open("data.txt",'r') as fin, open("output.txt","w") as fout:
    for line in fin:
        fout.write(line.upper())

# %% [markdown]
# #### Practice: Write only lines containing the word "ML"

# %%
## 3. CSV BASICS (WITHOUT csv MODULE)
### 3.1 Sample CSV file (students.csv)

# %%
with open("student.csv", 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# name,age,score
# Ravi,20,85
# Anita,21,90
# Kiran,19,78

# %% [markdown]
# #### Practice : Skip the header row
# ### 3.3 Splitting CSV columns manually

# %%
with open('student.csv','r') as f:
    header = next(f)
    for line in f:
        name , age , score = line.strip().split(',')
        print(name,age,score)
# Out:
# Ravi 20 85
# Anita 21 90
# Kiran 19 78

# %% [markdown]
# #### Practice: Convert age and score to integers
# ### 3.4 Calculating average from CSV

# %%
total = 0
count = 0
with open("student.csv", 'r') as f:
    next(f)
    for line in f:
        _,_ , score = line.strip().split(',')
        total += int(score)
        count +=1
        
print("Avarage score:",total/count)
# Out:
# Avarage score: 84.33333333333333

# %% [markdown]
# #### Practice: Find the maximum score
# ### 4. USING csv MODULE (REAL-WORLD WAY)
# #### 4.1 Reading CSV using csv.reader

# %%
import csv 
with open("student.csv", 'r') as f:
    reader = csv.reader(f)
    header = next(reader)
    for row in reader:
        print(row)
# Out:
# ['Ravi', '20', '85']
# ['Anita', '21', '90']
# ['Kiran', '19', '78']

# %% [markdown]
# #### Practice: Print only names
# ### 4.2 Accessing columns safely

# %%
import csv

with open("student.csv",'r') as f:
    reader = csv.reader(f)
    next(reader)
    
    for name, age, score in reader:
        print(name, int(score))
# Out:
# Ravi 85
# Anita 90
# Kiran 78

# %% [markdown]
# ### Writing to a CSV file

# %%
import csv
data = [
    ['name', 'age', 'score'],
    ['Aman',22, 88],
    ["Neha",21,92]
]

with open('new_student.csv', 'w',newline="") as f:
    write = csv.writer(f)
    write.writerows(data)

# %% [markdown]
# #### Practice: Add a new student row programmatically
# ### 5.1 Filter rows based on condition

# %%
with open('new_student.csv','r') as f:
    for line in f:
        print(line)
# Out:
# name,age,score
#
# Aman,22,88
#
# Neha,21,92

# %%
data_new =[
    ['name','age','score'],
    ["Neha",23,56],
    ["Rantu",34,78],
    ['Aloke', 40, 90]
]

with open('new_student.csv','a') as f:
    writer = csv.writer(f)
    writer.writerows(data_new[1:])

# %%
with open('new_student.csv','r') as f:
    for line in f:
        print(line)
# Out:
# name,age,score
#
# Aman,22,88
#
# Neha,21,92
#
# Neha,23,56
#
#
#
# Rantu,34,78
#
#
#
# Aloke,40,90

# %% [markdown]
# #### Practice: Save filtered rows to a new CSV
# ### 5.2 Feature extraction form CSV

# %%
ages =[]
scores = []
with open('new_student.csv', 'r') as f:
    reader = csv.DictReader(f)
#     print(list(reader))
    for row in reader:
        ages.append(int(row['age']))
        scores.append(int(row['score']))
        
print(ages)
print(scores)
# This is exactly how ML datasets are prepared.
# Out:
# [22, 21, 23, 34, 40]
# [88, 92, 56, 78, 90]

# %%
name = []
score = []
with open('student.csv','r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        name.append(row['name'])
        score.append(int(row['score']))
name
# Out:
# ['Ravi', 'Anita', 'Kiran']

# %% [markdown]
# ### 5.3 Train like pattern

# %%
class Dataset:
    def __init__(self,filename):
        self.data =[]
        with open(filename,'r') as f:
            reader = csv.DictReader(f)
            for row in reader:
                self.data.append(row)
                
dataset = Dataset('student.csv')
dataset.data
# Out:
# [{'name': 'Ravi', 'age': '20', 'score': '85'},
#  {'name': 'Anita', 'age': '21', 'score': '90'},
#  {'name': 'Kiran', 'age': '19', 'score': '78'}]

# %%
class Dataset:
    def __init__(self,filename):
        self.filename =filename
        self.data = []
        with open(self.filename,'r') as f:
            reader = csv.DictReader(f)
            for row in reader:
                self.data.append(row)
                
#         return self.data
dataset = Dataset('new_student.csv')
dataset.data
# Out:
# [{'name': 'Aman', 'age': '22', 'score': '88'},
#  {'name': 'Neha', 'age': '21', 'score': '92'},
#  {'name': 'Neha', 'age': '23', 'score': '56'},
#  {'name': 'Rantu', 'age': '34', 'score': '78'},
#  {'name': 'Aloke', 'age': '40', 'score': '90'}]

# %% [markdown]
# #### Practice: Add a method get_scores() that returns a list of scores

# %% [markdown]
# ### Example usage of os
# #### 1. Verify your current working directory

# %%
import os 
print(os.getcwd())
# Out:
# D:\ML_Road_Map\AI-ML-Repository-

# %% [markdown]
# ### Practice
# #### Run this from a .py file and from a .ipynb
# #### Note the difference
#
# ### 2. Check if key files exist

# %%
import os
print(os.path.exists('data.txt'))
print(os.path.exists('student.csv'))
print(os.path.exists('experiments'))
# Out:
# True
# True
# True

# %% [markdown]
# ### Practice
# #### Check existence of Lambda Function.ipynb
# #### Check existence of .gitignore
# ### 3. Convert relative path to absolute path

# %%
import os
file_path = 'student.csv'
print(os.path.abspath(file_path))
# Out:
# D:\ML_Road_Map\AI-ML-Repository-\student.csv

# %% [markdown]
# ### Practice: Print absolute paths of:
# #### Calculator_class.py
# #### Functions_exercises.ipynb
# ### 4. List all files in your repository (dataset exploration)

# %%
import os 
files = os.listdir('.')
for f in files:
    print(f)
# Out:
# .git
# .gitignore
# .ipynb_checkpoints
# Calculator_class.py
# class and object.ipynb
# class_inheritanceExample.py
# data.txt
# experiments
# Functions_exercises.ipynb
# hello.txt
# inheritace_contract_practice.py
# Inheritance_Template_Method.py
# Lambda Function.ipynb
# new_student.csv
# output.txt
# pandasTutorials.ipynb
# pointClass_distance.py
# sixth_month_roadmap.docx
# sixth_month_roadmap.pdf
# student.csv
# Untitled.ipynb
# Working_withFiles.ipynb

# %% [markdown]
# ### Practice:
# #### Filter and print only .py files
# #### Filter and print only .ipynb files
# ### 5. Identify file vs folder (important for automation)

# %%
import os 
for item in os.listdir('.'):
    if os.path.isfile(item):
        print("File :",item)
    elif os.path.isdir(item):
        print("Folder:",item)
# Out:
# Folder: .git
# File : .gitignore
# Folder: .ipynb_checkpoints
# File : Calculator_class.py
# File : class and object.ipynb
# File : class_inheritanceExample.py
# File : data.txt
# Folder: experiments
# File : Functions_exercises.ipynb
# File : hello.txt
# File : inheritace_contract_practice.py
# File : Inheritance_Template_Method.py
# File : Lambda Function.ipynb
# File : new_student.csv
# File : output.txt
# File : pandasTutorials.ipynb
# File : pointClass_distance.py
# File : sixth_month_roadmap.docx
# File : sixth_month_roadmap.pdf
# File : student.csv
# File : Untitled.ipynb
# File : Working_withFiles.ipynb

# %%
import os
for item in os.listdir('.'):
    print(item)
# Out:
# .git
# .gitignore
# .ipynb_checkpoints
# Calculator_class.py
# class and object.ipynb
# class_inheritanceExample.py
# data.txt
# experiments
# Functions_exercises.ipynb
# hello.txt
# inheritace_contract_practice.py
# Inheritance_Template_Method.py
# Lambda Function.ipynb
# new_student.csv
# output.txt
# pandasTutorials.ipynb
# pointClass_distance.py
# sixth_month_roadmap.docx
# sixth_month_roadmap.pdf
# student.csv
# Untitled.ipynb
# Working_withFiles.ipynb

# %% [markdown]
# ### Practice:
# #### Count total number of Python files
# #### Count total number of notebooks
# ### Work with nested folders(experiments/)

# %%
import os
run_path = os.path.join("experiments","run_02")
os.makedirs(run_path,exist_ok = True)

# %%
### Save experiment output
log_file = os.path.join(run_path, 'results.txt')

with open(log_file, 'w') as f:
    f.write("accuracy=0.91\n loss = 0.08")

# %% [markdown]
# ### Read and copy files programmatically
# #### Copy data.txt into experiment folder

# %%
import os
import shutil

src = 'data.txt'
dst = os.path.join('experiments', 'run_01','data_copy.txt')

shutil.copy(src,dst)
# Out:
# 'experiments\\run_01\\data_copy.txt'

# %%
import os
import shutil

src = 'data.txt'
dst = os.path.join('experiments/run_02','copy_data.txt')

shutil.copy(src,dst)
# Out:
# 'experiments/run_02\\copy_data.txt'

# %% [markdown]
# ### 8. Walk through entire repository

# %%
import os 
for root, dirs, files in os.walk('.'):
    for file in files:
        print(os.path.join(root,file))
# Out:
# .\.gitignore
# .\Calculator_class.py
# .\class and object.ipynb
# .\class_inheritanceExample.py
# .\data.txt
# .\Functions_exercises.ipynb
# .\hello.txt
# .\inheritace_contract_practice.py
# .\Inheritance_Template_Method.py
# .\Lambda Function.ipynb
# .\new_student.csv
# .\output.txt
# .\pandasTutorials.ipynb
# .\pointClass_distance.py
# .\sixth_month_roadmap.docx
# .\sixth_month_roadmap.pdf
# .\student.csv
# .\Untitled.ipynb
# .\Working_withFiles.ipynb
# .\.git\.COMMIT_EDITMSG.swp
# .\.git\COMMIT_EDITMSG
# .\.git\config
# .\.git\description
# .\.git\HEAD
# .\.git\index
# .\.git\packed-refs
# .\.git\hooks\applypatch-msg.sample
# .\.git\hooks\commit-msg.sample
# .\.git\hooks\fsmonitor-watchman.sample
# .\.git\hooks\post-update.sample
# .\.git\hooks\pre-applypatch.sample
# .\.git\hooks\pre-commit.sample
# .\.git\hooks\pre-merge-commit.sample
# .\.git\hooks\pre-push.sample
# .\.git\hooks\pre-rebase.sample
# .\.git\hooks\pre-receive.sample
# .\.git\hooks\prepare-commit-msg.sample
# .\.git\hooks\push-to-checkout.sample
# .\.git\hooks\sendemail-validate.sample
# .\.git\hooks\update.sample
# .\.git\info\exclude
# .\.git\logs\HEAD
# .\.git\logs\refs\heads\main
# .\.git\logs\refs\remotes\origin\HEAD
# .\.git\logs\refs\remotes\origin\main
# .\.git\objects\06\69807ec3a0d3ee52d818474b0c7c97369ef101
# .\.git\objects\08\5c58f689ad6c76167804fc7191d5762c3562a6
# .\.git\objects\0d\70b4cf13d12a8ab4c48ef8f6e54d6b0340b88c
# .\.git\objects\19\84eadd94b587af4563b41cd4a4d4e97fdfc1f2
# .\.git\objects\2a\3308de5ab9d10fe0f0e1912cf875ecb5a1ef32
# .\.git\objects\2a\704573717f24f6f4153dba74b04a8215daa839
# .\.git\objects\2f\c8930df68936352622656186ecd07589015a46
# .\.git\objects\33\2bd5cb6e48853854768e6cf5f0c618846099c0
# .\.git\objects\36\3fcab7ed6e9634e198cf5555ceb88932c9a245
# .\.git\objects\36\632759be13e5b0babc8eab222a8ac8c5f35162
# .\.git\objects\38\74f593a342430815a87112e88972d0160d72e8
# .\.git\objects\4f\9d27d4827b66eb066ea25c231e87f3d54d97cd
# .\.git\objects\58\0547309871558c3df00b0b3622c09fb546b8a5
# .\.git\objects\5a\9a62ec409126c3cc04fdd15ff4a6aa38a6145f
# .\.git\objects\5f\648aadea4352b4893525f33c5edca1255899d6
# .\.git\objects\82\af6a07971149f2273f01d1904faa5db00dc162
# .\.git\objects\8e\244a5a3048cb6abebe1537b4ce618d85a1061b
# .\.git\objects\8f\1c360fe44769281786a4f9764f37934970420b
# .\.git\objects\92\d38f020b2db03bb7189d2d46913a5f72d3b362
# .\.git\objects\a1\616cdeae459e491d10c150ab414362bd5571d0
# .\.git\objects\a4\32768cae222a09d0aba987742c82a61f1d9e89
# .\.git\objects\a5\5b3594fdd50caf4f958cc6b2e64b463a2019ef
# .\.git\objects\ae\08ddd8db57b7e163350043a9bae366f79624b1
# .\.git\objects\b4\f19c04e6f98a17155b1c9ee23cdabe2ecc2634
# .\.git\objects\bc\5325791e7cf4b0623b7518b4e0cc9c499e74e5
# .\.git\objects\c3\647c423eb1ea036edd03f869bfc6b65a3a9ade
# .\.git\objects\d9\7167c783a21409c37880854c25379437a12d62
# .\.git\objects\df\2dffc336eab2f9a6d26f16e5a76d87bffea8a9
# .\.git\objects\e9\925fdb3698788bf752a4f2bed6eb1789f97960
# .\.git\objects\e9\c90b7b99f51dd5cc210432f2250f21ec40881c
# .\.git\objects\f6\f0cc12c1c106ec5f9e720fb5bc804526303d8c
# .\.git\objects\fd\c448a457d22fce705588ce50072fc33421e96f
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.idx
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.pack
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.rev
# .\.git\refs\heads\main
# .\.git\refs\remotes\origin\HEAD
# .\.git\refs\remotes\origin\main
# .\.ipynb_checkpoints\class and object-checkpoint.ipynb
# .\.ipynb_checkpoints\Lambda Function-checkpoint.ipynb
# .\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# .\.ipynb_checkpoints\Working_withFiles-checkpoint.ipynb
# .\experiments\run_01\data_copy.txt
# .\experiments\run_02\copy_data.txt
# .\experiments\run_02\results.txt

# %% [markdown]
# ### Practice:
# #### Count how many .txt files exist
# #### Count how many .csv files exist

# %%
import os
import collections
csv_count = 0 
txt_count = 0 

file_type_counts = collections.defaultdict(int)
for root, dirs, files in os.walk('.'):
    for file in files:
        full_path = os.path.join(root,file)
        name, ext = os.path.splitext(file)
        ext = ext.lower()
        if ext == ".csv":
            csv_count += 1
        elif ext == ".txt":
            txt_count +=1
            
        file_type_counts[ext]+=1
        
print("-"*30)
print(f"File Count Summary: ")
print(f"Total .csv files found: **{csv_count}**")
print(f"Total .csv files found: **{txt_count}**")
print("-"*30)

print('Detailed File Type Counts:')
for ext, count in sorted(file_type_counts.items()):
    if ext:
        print(f"  {ext}: {count}")
# Out:
# ------------------------------
# File Count Summary:
# Total .csv files found: **2**
# Total .csv files found: **6**
# ------------------------------
# Detailed File Type Counts:
#   .csv: 2
#   .docx: 1
#   .idx: 1
#   .ipynb: 10
#   .pack: 1
#   .pdf: 1
#   .py: 5
#   .rev: 1
#   .sample: 14
#   .swp: 1
#   .txt: 6

# %%
import os 
import collections

csv_count = 0
txt_count = 0 

for root, dirs, files in os.walk('.'):
    for file in files:
        name,ext = os.path.splitext(file)
        ext = ext.lower()
        if ext == '.csv':
            csv_count+=1
        elif ext == '.txt':
            txt_count+=1
            
        file_type_counts[ext] += 1
        
print("-"*30)
print(f"File Count Summary:")
print(f"Total .csv files found: **{csv_count}")
print(f"Total .csv files found: **{txt_count}")
print("-"*30)
# Out:
# ------------------------------
# File Count Summary:
# Total .csv files found: **2
# Total .csv files found: **6
# ------------------------------

# %% [markdown]
# ### 9. Ignore system folders like .ipynb_checkpoints

# %%
import os
for root, dirs, files in os.walk("."):
    if ".ipynb_checkpoints" in dirs:
        dirs.remove(".ipynb_checkpoints")
    for file in files:
        print(os.path.join(root,file))
# Out:
# .\.gitignore
# .\Calculator_class.py
# .\class and object.ipynb
# .\class_inheritanceExample.py
# .\data.txt
# .\Functions_exercises.ipynb
# .\hello.txt
# .\inheritace_contract_practice.py
# .\Inheritance_Template_Method.py
# .\Lambda Function.ipynb
# .\new_student.csv
# .\output.txt
# .\pandasTutorials.ipynb
# .\pointClass_distance.py
# .\sixth_month_roadmap.docx
# .\sixth_month_roadmap.pdf
# .\student.csv
# .\Untitled.ipynb
# .\Working_withFiles.ipynb
# .\.git\.COMMIT_EDITMSG.swp
# .\.git\COMMIT_EDITMSG
# .\.git\config
# .\.git\description
# .\.git\HEAD
# .\.git\index
# .\.git\packed-refs
# .\.git\hooks\applypatch-msg.sample
# .\.git\hooks\commit-msg.sample
# .\.git\hooks\fsmonitor-watchman.sample
# .\.git\hooks\post-update.sample
# .\.git\hooks\pre-applypatch.sample
# .\.git\hooks\pre-commit.sample
# .\.git\hooks\pre-merge-commit.sample
# .\.git\hooks\pre-push.sample
# .\.git\hooks\pre-rebase.sample
# .\.git\hooks\pre-receive.sample
# .\.git\hooks\prepare-commit-msg.sample
# .\.git\hooks\push-to-checkout.sample
# .\.git\hooks\sendemail-validate.sample
# .\.git\hooks\update.sample
# .\.git\info\exclude
# .\.git\logs\HEAD
# .\.git\logs\refs\heads\main
# .\.git\logs\refs\remotes\origin\HEAD
# .\.git\logs\refs\remotes\origin\main
# .\.git\objects\06\69807ec3a0d3ee52d818474b0c7c97369ef101
# .\.git\objects\08\5c58f689ad6c76167804fc7191d5762c3562a6
# .\.git\objects\0d\70b4cf13d12a8ab4c48ef8f6e54d6b0340b88c
# .\.git\objects\19\84eadd94b587af4563b41cd4a4d4e97fdfc1f2
# .\.git\objects\2a\3308de5ab9d10fe0f0e1912cf875ecb5a1ef32
# .\.git\objects\2a\704573717f24f6f4153dba74b04a8215daa839
# .\.git\objects\2f\c8930df68936352622656186ecd07589015a46
# .\.git\objects\33\2bd5cb6e48853854768e6cf5f0c618846099c0
# .\.git\objects\36\3fcab7ed6e9634e198cf5555ceb88932c9a245
# .\.git\objects\36\632759be13e5b0babc8eab222a8ac8c5f35162
# .\.git\objects\38\74f593a342430815a87112e88972d0160d72e8
# .\.git\objects\4f\9d27d4827b66eb066ea25c231e87f3d54d97cd
# .\.git\objects\58\0547309871558c3df00b0b3622c09fb546b8a5
# .\.git\objects\5a\9a62ec409126c3cc04fdd15ff4a6aa38a6145f
# .\.git\objects\5f\648aadea4352b4893525f33c5edca1255899d6
# .\.git\objects\82\af6a07971149f2273f01d1904faa5db00dc162
# .\.git\objects\8e\244a5a3048cb6abebe1537b4ce618d85a1061b
# .\.git\objects\8f\1c360fe44769281786a4f9764f37934970420b
# .\.git\objects\92\d38f020b2db03bb7189d2d46913a5f72d3b362
# .\.git\objects\a1\616cdeae459e491d10c150ab414362bd5571d0
# .\.git\objects\a4\32768cae222a09d0aba987742c82a61f1d9e89
# .\.git\objects\a5\5b3594fdd50caf4f958cc6b2e64b463a2019ef
# .\.git\objects\ae\08ddd8db57b7e163350043a9bae366f79624b1
# .\.git\objects\b4\f19c04e6f98a17155b1c9ee23cdabe2ecc2634
# .\.git\objects\bc\5325791e7cf4b0623b7518b4e0cc9c499e74e5
# .\.git\objects\c3\647c423eb1ea036edd03f869bfc6b65a3a9ade
# .\.git\objects\d9\7167c783a21409c37880854c25379437a12d62
# .\.git\objects\df\2dffc336eab2f9a6d26f16e5a76d87bffea8a9
# .\.git\objects\e9\925fdb3698788bf752a4f2bed6eb1789f97960
# .\.git\objects\e9\c90b7b99f51dd5cc210432f2250f21ec40881c
# .\.git\objects\f6\f0cc12c1c106ec5f9e720fb5bc804526303d8c
# .\.git\objects\fd\c448a457d22fce705588ce50072fc33421e96f
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.idx
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.pack
# .\.git\objects\pack\pack-39c4ba75bbe970e861fe07b66bfdf9c2e431755f.rev
# .\.git\refs\heads\main
# .\.git\refs\remotes\origin\HEAD
# .\.git\refs\remotes\origin\main
# .\experiments\run_01\data_copy.txt
# .\experiments\run_02\copy_data.txt
# .\experiments\run_02\results.txt

# %% [markdown]
# ### 10. Dynamic path resolution

# %%
import os 
base_dir = os.path.dirname(os.path.abspath(__file__))
data_file = os.path.join(base_dir, 'student.csv')
print(data_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 import os
# ----> 2 base_dir = os.path.dirname(os.path.abspath(__file__))
#       3 data_file = os.path.join(base_dir, 'student.csv')
#       4 print(data_file)
#
# NameError: name '__file__' is not defined

# %% [markdown]
# ### 11. Auto-detect file types

# %%
import os 
summary ={
    "python":0,
    "notebooks":0,
    "csv":0,
    "text":0
}
for f in os.listdir("."):
    if f.endswith(".py"):
        summary['python'] +=1
    elif f.endswith('.ipynb'):
        summary['notebooks']+=1
    elif f.endswith(".csv"):
        summary['csv']+=1
    elif f.endswith(".txt"):
#     elif f.endswith(".txt"):
        summary['text']+=1
        
print(summary)
# Out:
# {'python': 5, 'notebooks': 6, 'csv': 2, 'text': 3}

# %%
import os

summary = {
    "python": 0,
    "notebooks": 0,
    "csv": 0,
    "text": 0
}

for f in os.listdir("."):
    if f.endswith(".py"):
        summary["python"] += 1
    elif f.endswith(".ipynb"):
        summary["notebooks"] += 1
    elif f.endswith(".csv"):
        summary["csv"] += 1
    elif f.endswith(".txt"):
        summary["text"] += 1

print(summary)
# Out:
# {'python': 5, 'notebooks': 6, 'csv': 2, 'text': 3}

# %%
import os

summary={
    "python":0,
    "notebooks":0,
    "csv":0,
    "text":0
}

for f in os.listdir('.'):
    if f.endswith(".py"):
        summary['python']+=1
    elif f.endswith("ipynb"):
        summary['notebooks']+=1
    elif f.endswith(".csv"):
        summary['csv']+=1
    elif f.endswith(".txt"):
        summary['text']+=1
        
print(summary)
# Out:
# {'python': 5, 'notebooks': 6, 'csv': 2, 'text': 3}

# %% [markdown]
# ### 📊 Exploratory Data Analysis (EDA) with Pandas – Iris Dataset

# %%
import pandas as pd
df = pd.read_csv("iris.csv")
df.shape
# Out:
# (150, 5)

# %%
print(df.mean(numeric_only=True))
print(df.median(numeric_only=True))
print(df.max(numeric_only=True))
print(df.min(numeric_only=True))
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64
# sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64
# sepal.length    7.9
# sepal.width     4.4
# petal.length    6.9
# petal.width     2.5
# dtype: float64
# sepal.length    4.3
# sepal.width     2.0
# petal.length    1.0
# petal.width     0.1
# dtype: float64

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df_dropped = df.dropna()

# %%
df_dropped.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df['sepal.length'].fillna(df['sepal.length'].mean(),inplace = True)
df['sepal.width'].fillna(df['sepal.width'].mean(), inplace =True)

# %% [markdown]
# ### Histogram (distribution of one feature)

# %%
import matplotlib.pyplot as plt
plt.hist(df['sepal.length'],bins=50)
plt.xlabel('sepal length')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
plt.hist(df['sepal.width'],bins=50)
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.title('The Distribution of Sepal Width')
plt.show()

# %% [markdown]
# ### Scatter plot (relationship between two features)
# #### Example: Sepal length vs Petal length

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
plt.scatter(df['sepal.length'],df['sepal.width'])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal vs Petal Length")
plt.show()


# Why important:
# feature correlation
# linear vs non-linear patterns
# feature selection

# %% [markdown]
# ### Boxplot (outlier detection)

# %%
plt.boxplot(df['petal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29afd1d5e90>,
#   <matplotlib.lines.Line2D at 0x29afcd25590>],
#  'caps': [<matplotlib.lines.Line2D at 0x29afcd26250>,
#   <matplotlib.lines.Line2D at 0x29afcd25210>],
#  'boxes': [<matplotlib.lines.Line2D at 0x29afc76c6d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29afd24e250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29afce94190>],
#  'means': []}

# %% [markdown]
# Practice exercises (do these)
#
# 1. Plot histogram for petal_length
# 2. Create scatter plot: petal_width vs petal_length
# 3. Draw boxplots for all numeric columns
# 4. Normalize one column manually: (x - mean) / std
# 5. Separate: features (X), target (y)
